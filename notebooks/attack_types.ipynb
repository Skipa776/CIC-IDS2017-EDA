# %%
import pandas as pd

combined_df = pd.read_csv("../data/processed/cicids2017_clean.csv")

# %%
combined_df.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0                22            166                  1                       1
# 1             60148             83                  1                       2
# 2               443         188867                  9                       7
# 3               443         213931                 10                       8
# 4               443           3085                  1                       2
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                            0                            0
# 1                            0                            0
# 2                          528                         4513
# 3                          563                         4549
# 4                            6                           44
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# ...
